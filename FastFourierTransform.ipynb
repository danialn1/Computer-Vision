# %% [markdown]
# **DANIAL NASIR**
# **19I-1861**
# **Computer Vision Assignment 2**

# %% [markdown]
# Importing useful libraries

# %%
import cv2
import numpy as np
import math
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
#Reading an image
img = cv2.imread('sample.jpeg')
a=cv2.resize(img, (300, 300))
gray = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(a)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FFB2532DB90>

# %%
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x7FFB25335DD0>

# %%
#First we will calculate the horizontal change
gX = cv2.Sobel(gray, cv2.CV_64F, 1, 0)

# %%
gX
# Out:
# array([[   0., -100.,   54., ..., -168.,  -32.,    0.],
#        [   0.,  -99.,   32., ...,  -74.,    2.,    0.],
#        [   0.,  -91.,  -23., ...,   19.,   31.,    0.],
#        ...,
#        [   0.,   -5.,    3., ...,   14.,   15.,    0.],
#        [   0.,    3.,   21., ...,   38.,   26.,    0.],
#        [   0.,    6.,   30., ...,   46.,   28.,    0.]])

# %%
#Secondly we will calculate the vertical change
gY = cv2.Sobel(gray, cv2.CV_64F, 0, 1)

# %%
gY
# Out:
# array([[  0.,   0.,   0., ...,   0.,   0.,   0.],
#        [  6.,   7., -14., ..., 172., 300., 334.],
#        [  4.,  11., -15., ..., -11., -17., -22.],
#        ...,
#        [-36., -31., -17., ..., -28.,  -3.,   6.],
#        [-10.,  -7.,   5., ...,   4.,  14.,  16.],
#        [  0.,   0.,   0., ...,   0.,   0.,   0.]])

# %%
#gradient magnitude
magnitude = np.sqrt((gX ** 2) + (gY ** 2))

# %%
magnitude
# Out:
# array([[  0.        , 100.        ,  54.        , ..., 168.        ,
#          32.        ,   0.        ],
#        [  6.        ,  99.24716621,  34.92849839, ..., 187.24315742,
#         300.00666659, 334.        ],
#        [  4.        ,  91.66242414,  27.45906044, ...,  21.9544984 ,
#          35.35533906,  22.        ],
#        ...,
#        [ 36.        ,  31.40063694,  17.2626765 , ...,  31.30495168,
#          15.29705854,   6.        ],
#        [ 10.        ,   7.61577311,  21.58703314, ...,  38.20994635,
#          29.52964612,  16.        ],
#        [  0.        ,   6.        ,  30.        , ...,  46.        ,
#          28.        ,   0.        ]])

# %%
#gradient orientation
orientation = np.arctan2(gY, gX) * (180 / np.pi) % 180

# %%
orientation
# Out:
# array([[  0.        ,   0.        ,   0.        , ...,   0.        ,
#           0.        ,   0.        ],
#        [ 90.        , 175.95551443, 156.37062227, ..., 113.2789492 ,
#          89.6180338 ,  90.        ],
#        [ 90.        , 173.10757688,  33.11134196, ..., 149.93141718,
#         151.26020471,  90.        ],
#        ...,
#        [ 90.        ,  80.83765295, 100.0079798 , ..., 116.56505118,
#         168.69006753,  90.        ],
#        [ 90.        , 113.19859051,  13.39249775, ...,   6.00900596,
#          28.30075577,  90.        ],
#        [  0.        ,   0.        ,   0.        , ...,   0.        ,
#           0.        ,   0.        ]])

# %%
(fig, axs) = plt.subplots(nrows=1, ncols=3, figsize=(8, 4))
axs[0].imshow(gray, cmap="gray")
axs[1].imshow(magnitude, cmap="jet")
axs[2].imshow(orientation, cmap="jet")
axs[0].set_title("Grayscale")
axs[1].set_title("Gradient Magnitude")
axs[2].set_title("Gradient Orientation")
# Out:
# Text(0.5, 1.0, 'Gradient Orientation')
